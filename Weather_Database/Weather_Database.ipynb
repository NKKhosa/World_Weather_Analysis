# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time 
from datetime import datetime
from scipy.stats import linregress


# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities. 
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the nearest cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 fo logging purposes. 
    if (i % 50 == 0 and i >= 50): 
        set_count += 1
        record_count = 1 
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve the data. 
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity= city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(), 
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp, 
                          "Humidity": city_humidity, 
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, 
                          "Weather Description": city_description})

    # # If an error is experienced skip the city.
    except: 
        print("City not found. Skipping...")
        pass

# Indicate that the data loading is complete. 
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | marang
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | panuco
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 1 | canton
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | sioux lookout
# Processing Record 21 of Set 1 | ixtapa
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | yurla
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | north platte
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | tilichiki
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | guaraciaba do norte
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 1 | manosque
# Processing Record 36 of Set 1 | riyadh
# Processing Record 37 of Set 1 | yamada
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | komsomolskiy
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | darnah
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | nanortalik
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | kununurra
# Processing Record 6 of Set 2 | sohag
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | barahona
# Processing Record 9 of Set 2 | weinan
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | ondjiva
# Processing Record 13 of Set 2 | semnan
# Processing Record 14 of Set 2 | barmer
# Processing Record 15 of Set 2 | thunder bay
# Processing Record 16 of Set 2 | la asuncion
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | souillac
# Processing Record 21 of Set 2 | pochutla
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | gilbues
# Processing Record 24 of Set 2 | narasannapeta
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | mahibadhoo
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | jiaozuo
# Processing Record 30 of Set 2 | quatre cocos
# Processing Record 31 of Set 2 | vardo
# Processing Record 32 of Set 2 | acapulco
# Processing Record 33 of Set 2 | douglas
# Processing Record 34 of Set 2 | yantal
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | havelock
# Processing Record 38 of Set 2 | havoysund
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | steamboat springs
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | rocha
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | oudtshoorn
# Processing Record 45 of Set 2 | tazovskiy
# Processing Record 46 of Set 2 | sakakah
# Processing Record 47 of Set 2 | kemin
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | chilia veche
# Processing Record 50 of Set 2 | camacha
# Processing Record 1 of Set 3 | alice springs
# Processing Record 2 of Set 3 | vyritsa
# Processing Record 3 of Set 3 | husavik
# Processing Record 4 of Set 3 | muros
# Processing Record 5 of Set 3 | westport
# Processing Record 6 of Set 3 | codrington
# Processing Record 7 of Set 3 | hofn
# Processing Record 8 of Set 3 | plettenberg bay
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | belmonte
# Processing Record 11 of Set 3 | iberia
# Processing Record 12 of Set 3 | kyaikkami
# Processing Record 13 of Set 3 | hudson bay
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | bud
# Processing Record 16 of Set 3 | tiarei
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | sao jose da coroa grande
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | manono
# Processing Record 24 of Set 3 | moron
# Processing Record 25 of Set 3 | nouadhibou
# Processing Record 26 of Set 3 | archidona
# Processing Record 27 of Set 3 | siocon
# Processing Record 28 of Set 3 | grand-lahou
# Processing Record 29 of Set 3 | deputatskiy
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | kattivakkam
# Processing Record 32 of Set 3 | khasan
# Processing Record 33 of Set 3 | lichuan
# Processing Record 34 of Set 3 | vestmannaeyjar
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | san cristobal
# Processing Record 37 of Set 3 | talaya
# Processing Record 38 of Set 3 | sur
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | brewster
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | wad rawah
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | marion
# Processing Record 47 of Set 3 | derzhavinsk
# Processing Record 48 of Set 3 | lewiston
# Processing Record 49 of Set 3 | puerto cabezas
# Processing Record 50 of Set 3 | formosa
# Processing Record 1 of Set 4 | ancud
# Processing Record 2 of Set 4 | booue
# Processing Record 3 of Set 4 | jibuti
# Processing Record 4 of Set 4 | gari
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | magistralnyy
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | turayf
# Processing Record 9 of Set 4 | iqaluit
# Processing Record 10 of Set 4 | upata
# Processing Record 11 of Set 4 | ngunguru
# Processing Record 12 of Set 4 | ylivieska
# Processing Record 13 of Set 4 | ayagoz
# Processing Record 14 of Set 4 | vila franca do campo
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | desaguadero
# Processing Record 17 of Set 4 | north bay
# Processing Record 18 of Set 4 | robinson
# Processing Record 19 of Set 4 | carutapera
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | bay roberts
# Processing Record 22 of Set 4 | portland
# Processing Record 23 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | yelizovo
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 4 | rio grande
# Processing Record 30 of Set 4 | nome
# Processing Record 31 of Set 4 | bara
# Processing Record 32 of Set 4 | barcelos
# Processing Record 33 of Set 4 | beitbridge
# Processing Record 34 of Set 4 | port moresby
# Processing Record 35 of Set 4 | moose factory
# Processing Record 36 of Set 4 | luganville
# Processing Record 37 of Set 4 | mayumba
# Processing Record 38 of Set 4 | waipawa
# Processing Record 39 of Set 4 | surgut
# Processing Record 40 of Set 4 | yangambi
# Processing Record 41 of Set 4 | tolaga bay
# Processing Record 42 of Set 4 | salaverry
# Processing Record 43 of Set 4 | hirara
# Processing Record 44 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 4 | clearwater
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | mardin
# Processing Record 48 of Set 4 | grindavik
# Processing Record 49 of Set 4 | labuhan
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | severo-kurilsk
# Processing Record 2 of Set 5 | namibe
# Processing Record 3 of Set 5 | saint-denis
# Processing Record 4 of Set 5 | cortez
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | washington
# Processing Record 8 of Set 5 | sao joao da barra
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | georgetown
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | takoradi
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 5 | izberbash
# Processing Record 16 of Set 5 | tomatlan
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | bathsheba
# Processing Record 19 of Set 5 | vangaindrano
# Processing Record 20 of Set 5 | mogadishu
# Processing Record 21 of Set 5 | mehamn
# Processing Record 22 of Set 5 | reconquista
# Processing Record 23 of Set 5 | dandong
# Processing Record 24 of Set 5 | kavaratti
# Processing Record 25 of Set 5 | nador
# Processing Record 26 of Set 5 | mingshui
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | veraval
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | kenora
# Processing Record 31 of Set 5 | humaita
# Processing Record 32 of Set 5 | baruun-urt
# Processing Record 33 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | lompoc
# Processing Record 37 of Set 5 | ormstown
# Processing Record 38 of Set 5 | ignacio zaragoza
# Processing Record 39 of Set 5 | maua
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | leningradskiy
# Processing Record 42 of Set 5 | west bay
# Processing Record 43 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 5 | chulman
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | mugur-aksy
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | san pedro
# Processing Record 50 of Set 5 | sorong
# Processing Record 1 of Set 6 | katobu
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | kualakapuas
# Processing Record 5 of Set 6 | urumqi
# Processing Record 6 of Set 6 | shizuishan
# Processing Record 7 of Set 6 | gonbad-e qabus
# Processing Record 8 of Set 6 | mazagao
# Processing Record 9 of Set 6 | bereda
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | najran
# Processing Record 12 of Set 6 | hervey bay
# Processing Record 13 of Set 6 | pljevlja
# Processing Record 14 of Set 6 | solnechnyy
# Processing Record 15 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | kpandae
# Processing Record 18 of Set 6 | puerto leguizamo
# Processing Record 19 of Set 6 | saint anthony
# Processing Record 20 of Set 6 | kodiak
# Processing Record 21 of Set 6 | tezu
# Processing Record 22 of Set 6 | aitape
# Processing Record 23 of Set 6 | waddan
# Processing Record 24 of Set 6 | pinyug
# Processing Record 25 of Set 6 | kaliganj
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | gariaband
# Processing Record 28 of Set 6 | svetlaya
# Processing Record 29 of Set 6 | ambon
# Processing Record 30 of Set 6 | sept-iles
# Processing Record 31 of Set 6 | mantes-la-jolie
# Processing Record 32 of Set 6 | arari
# Processing Record 33 of Set 6 | makat
# Processing Record 34 of Set 6 | berlevag
# Processing Record 35 of Set 6 | ruteng
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | murwara
# Processing Record 38 of Set 6 | sosva
# Processing Record 39 of Set 6 | axim
# Processing Record 40 of Set 6 | gamba
# Processing Record 41 of Set 6 | enkoping
# Processing Record 42 of Set 6 | srednekolymsk
# Processing Record 43 of Set 6 | bousso
# Processing Record 44 of Set 6 | bogatic
# Processing Record 45 of Set 6 | dukat
# Processing Record 46 of Set 6 | buraydah
# Processing Record 47 of Set 6 | pentecoste
# Processing Record 48 of Set 6 | tahe
# Processing Record 49 of Set 6 | harper
# Processing Record 50 of Set 6 | meulaboh
# Processing Record 1 of Set 7 | parabel
# Processing Record 2 of Set 7 | pokhara
# Processing Record 3 of Set 7 | maumere
# Processing Record 4 of Set 7 | katsina
# Processing Record 5 of Set 7 | chake chake
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | ahipara
# Processing Record 8 of Set 7 | bayan
# Processing Record 9 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | kibungo
# Processing Record 12 of Set 7 | mamlyutka
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | hanzhong
# Processing Record 15 of Set 7 | denpasar
# Processing Record 16 of Set 7 | mabaruma
# Processing Record 17 of Set 7 | deer lake
# Processing Record 18 of Set 7 | vestmanna
# Processing Record 19 of Set 7 | arlit
# Processing Record 20 of Set 7 | arman
# Processing Record 21 of Set 7 | nieuw amsterdam
# Processing Record 22 of Set 7 | tartus
# Processing Record 23 of Set 7 | port keats
# Processing Record 24 of Set 7 | chingola
# Processing Record 25 of Set 7 | carnarvon
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | sebinkarahisar
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | akyab
# Processing Record 30 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 31 of Set 7 | kilrush
# Processing Record 32 of Set 7 | faya
# Processing Record 33 of Set 7 | kroya
# Processing Record 34 of Set 7 | kasempa
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | anadyr
# Processing Record 37 of Set 7 | kisoro
# Processing Record 38 of Set 7 | lodja
# Processing Record 39 of Set 7 | victoria
# Processing Record 40 of Set 7 | salcininkai
# Processing Record 41 of Set 7 | bobcaygeon
# Processing Record 42 of Set 7 | nevsehir
# Processing Record 43 of Set 7 | shimoda
# Processing Record 44 of Set 7 | kangaatsiaq
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | iracoubo
# Processing Record 47 of Set 7 | salalah
# Processing Record 48 of Set 7 | vargem alta
# Processing Record 49 of Set 7 | sayansk
# Processing Record 50 of Set 7 | kem
# Processing Record 1 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 8 | nuzvid
# Processing Record 3 of Set 8 | bedesa
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | gangoh
# Processing Record 6 of Set 8 | burns lake
# Processing Record 7 of Set 8 | anklam
# Processing Record 8 of Set 8 | gat
# Processing Record 9 of Set 8 | springbok
# Processing Record 10 of Set 8 | jurm
# Processing Record 11 of Set 8 | piacabucu
# Processing Record 12 of Set 8 | dir
# Processing Record 13 of Set 8 | mugan
# Processing Record 14 of Set 8 | darhan
# Processing Record 15 of Set 8 | aklavik
# Processing Record 16 of Set 8 | poltava
# Processing Record 17 of Set 8 | chokurdakh
# Processing Record 18 of Set 8 | bantry
# Processing Record 19 of Set 8 | vieques
# Processing Record 20 of Set 8 | hualmay
# Processing Record 21 of Set 8 | fort walton beach
# Processing Record 22 of Set 8 | cassilandia
# Processing Record 23 of Set 8 | beringovskiy
# Processing Record 24 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 8 | bonthe
# Processing Record 26 of Set 8 | la brea
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | mezen
# Processing Record 29 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 8 | tornio
# Processing Record 31 of Set 8 | bang saphan
# Processing Record 32 of Set 8 | peterhead
# Processing Record 33 of Set 8 | manavalakurichi
# Processing Record 34 of Set 8 | kruisfontein
# Processing Record 35 of Set 8 | lima
# Processing Record 36 of Set 8 | cockburn town
# Processing Record 37 of Set 8 | pimentel
# Processing Record 38 of Set 8 | yarim
# Processing Record 39 of Set 8 | grand gaube
# Processing Record 40 of Set 8 | port shepstone
# Processing Record 41 of Set 8 | chunoyar
# Processing Record 42 of Set 8 | waingapu
# Processing Record 43 of Set 8 | manggar
# Processing Record 44 of Set 8 | jinka
# Processing Record 45 of Set 8 | great yarmouth
# Processing Record 46 of Set 8 | whitehorse
# Processing Record 47 of Set 8 | leh
# Processing Record 48 of Set 8 | sistranda
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 50 of Set 8 | palu
# Processing Record 1 of Set 9 | aksarka
# Processing Record 2 of Set 9 | shitanjing
# Processing Record 3 of Set 9 | roseburg
# Processing Record 4 of Set 9 | marathon
# Processing Record 5 of Set 9 | tighina
# Processing Record 6 of Set 9 | benjamin aceval
# Processing Record 7 of Set 9 | nalut
# Processing Record 8 of Set 9 | shingu
# Processing Record 9 of Set 9 | caranavi
# Processing Record 10 of Set 9 | znamenskoye
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | lazarev
# Processing Record 13 of Set 9 | blankenberge
# Processing Record 14 of Set 9 | buzmeyin
# Processing Record 15 of Set 9 | miri
# Processing Record 16 of Set 9 | ocampo
# Processing Record 17 of Set 9 | kalaleh
# Processing Record 18 of Set 9 | doha
# Processing Record 19 of Set 9 | stornoway
# Processing Record 20 of Set 9 | northam
# Processing Record 21 of Set 9 | lucapa
# Processing Record 22 of Set 9 | mareeba
# Processing Record 23 of Set 9 | kyzyl-suu
# Processing Record 24 of Set 9 | ust-kulom
# Processing Record 25 of Set 9 | mmabatho
# Processing Record 26 of Set 9 | otradnoye
# Processing Record 27 of Set 9 | aksu
# Processing Record 28 of Set 9 | maturin
# Processing Record 29 of Set 9 | port macquarie
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | yabrud
# Processing Record 32 of Set 9 | novikovo
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | kloulklubed
# Processing Record 35 of Set 9 | kapan
# Processing Record 36 of Set 9 | vanimo
# Processing Record 37 of Set 9 | george town
# Processing Record 38 of Set 9 | mount gambier
# Processing Record 39 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 9 | cidreira
# Processing Record 41 of Set 9 | ouegoa
# Processing Record 42 of Set 9 | saint george
# Processing Record 43 of Set 9 | vao
# Processing Record 44 of Set 9 | aldan
# Processing Record 45 of Set 9 | bambous virieux
# Processing Record 46 of Set 9 | maragogi
# Processing Record 47 of Set 9 | acajutla
# Processing Record 48 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 9 | valdivia
# Processing Record 50 of Set 9 | honiara
# Processing Record 1 of Set 10 | klaksvik
# Processing Record 2 of Set 10 | ambilobe
# Processing Record 3 of Set 10 | pangody
# Processing Record 4 of Set 10 | dindori
# Processing Record 5 of Set 10 | beneditinos
# Processing Record 6 of Set 10 | candido mendes
# Processing Record 7 of Set 10 | tadine
# Processing Record 8 of Set 10 | ust-tsilma
# Processing Record 9 of Set 10 | morro bay
# Processing Record 10 of Set 10 | santa cruz
# Processing Record 11 of Set 10 | ketchikan
# Processing Record 12 of Set 10 | benjamin constant
# Processing Record 13 of Set 10 | fairfield
# Processing Record 14 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 10 | khudumelapye
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | wiang sa
# Processing Record 18 of Set 10 | khilok
# Processing Record 19 of Set 10 | salmas
# Processing Record 20 of Set 10 | esna
# Processing Record 21 of Set 10 | opuwo
# Processing Record 22 of Set 10 | svetlyy
# Processing Record 23 of Set 10 | tiznit
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | acarau
# Processing Record 26 of Set 10 | prince rupert
# Processing Record 27 of Set 10 | smithers
# Processing Record 28 of Set 10 | katsuura
# Processing Record 29 of Set 10 | tual
# Processing Record 30 of Set 10 | cervo
# Processing Record 31 of Set 10 | puerto quijarro
# Processing Record 32 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 10 | ornskoldsvik
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | webuye
# Processing Record 36 of Set 10 | tateyama
# Processing Record 37 of Set 10 | ronneby
# Processing Record 38 of Set 10 | narino
# Processing Record 39 of Set 10 | fare
# Processing Record 40 of Set 10 | lavrentiya
# Processing Record 41 of Set 10 | bac lieu
# Processing Record 42 of Set 10 | amarkantak
# Processing Record 43 of Set 10 | oruro
# Processing Record 44 of Set 10 | kampong thum
# Processing Record 45 of Set 10 | columbus
# Processing Record 46 of Set 10 | togul
# Processing Record 47 of Set 10 | ullapool
# Processing Record 48 of Set 10 | tineo
# Processing Record 49 of Set 10 | samana
# Processing Record 50 of Set 10 | bela vista de goias
# Processing Record 1 of Set 11 | zavitinsk
# Processing Record 2 of Set 11 | zonguldak
# Processing Record 3 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 11 | maridi
# Processing Record 5 of Set 11 | contai
# Processing Record 6 of Set 11 | jatiroto
# Processing Record 7 of Set 11 | upington
# Processing Record 8 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 11 | sakti
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 11 | nanning
# Processing Record 13 of Set 11 | saint-pierre
# Processing Record 14 of Set 11 | chernaya kholunitsa
# Processing Record 15 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 17 of Set 11 | oranjemund
# Processing Record 18 of Set 11 | fairview
# Processing Record 19 of Set 11 | buala
# Processing Record 20 of Set 11 | cabo san lucas
# Processing Record 21 of Set 11 | urcos
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 11 | silver city
# Processing Record 25 of Set 11 | tiruchchirappalli
# Processing Record 26 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 11 | port-gentil
# Processing Record 28 of Set 11 | marystown
# Processing Record 29 of Set 11 | duz
# City not found. Skipping...
# Processing Record 30 of Set 11 | samarai
# Processing Record 31 of Set 11 | maningrida
# Processing Record 32 of Set 11 | tulsipur
# Processing Record 33 of Set 11 | guaraniacu
# Processing Record 34 of Set 11 | puerto del rosario
# Processing Record 35 of Set 11 | cap-aux-meules
# Processing Record 36 of Set 11 | alofi
# Processing Record 37 of Set 11 | catamarca
# Processing Record 38 of Set 11 | hoshcha
# Processing Record 39 of Set 11 | chakwal
# Processing Record 40 of Set 11 | pisco
# Processing Record 41 of Set 11 | paternion
# Processing Record 42 of Set 11 | phan thiet
# Processing Record 43 of Set 11 | richards bay
# Processing Record 44 of Set 11 | zhigansk
# Processing Record 45 of Set 11 | thinadhoo
# Processing Record 46 of Set 11 | north bend
# Processing Record 47 of Set 11 | mercedes
# Processing Record 48 of Set 11 | wa
# City not found. Skipping...
# Processing Record 49 of Set 11 | mae hong son
# Processing Record 50 of Set 11 | ca mau
# Processing Record 1 of Set 12 | praia da vitoria
# Processing Record 2 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | monte patria
# Processing Record 4 of Set 12 | nuuk
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | pangnirtung
# Processing Record 7 of Set 12 | edea
# Processing Record 8 of Set 12 | fallon
# Processing Record 9 of Set 12 | atar
# Processing Record 10 of Set 12 | nhulunbuy
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | erzin
# Processing Record 13 of Set 12 | manuk mangkaw
# Processing Record 14 of Set 12 | khromtau
# Processing Record 15 of Set 12 | jiuquan
# Processing Record 16 of Set 12 | puerto escondido
# Processing Record 17 of Set 12 | biak
# Processing Record 18 of Set 12 | zhanaozen
# Processing Record 19 of Set 12 | san antonio
# Processing Record 20 of Set 12 | tocopilla
# Processing Record 21 of Set 12 | batagay
# Processing Record 22 of Set 12 | ossora
# Processing Record 23 of Set 12 | jefferson city
# Processing Record 24 of Set 12 | pacific grove
# Processing Record 25 of Set 12 | cadillac
# Processing Record 26 of Set 12 | wisconsin rapids
# Processing Record 27 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 12 | altamira
# Processing Record 29 of Set 12 | zhanakorgan
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | yarke pole
# Processing Record 32 of Set 12 | flinders
# Processing Record 33 of Set 12 | nenjiang
# Processing Record 34 of Set 12 | agadir
# Processing Record 35 of Set 12 | avdon
# Processing Record 36 of Set 12 | kongolo
# Processing Record 37 of Set 12 | olga
# Processing Record 38 of Set 12 | nichinan
# Processing Record 39 of Set 12 | kimparana
# Processing Record 40 of Set 12 | sechura
# Processing Record 41 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 12 | constantine
# Processing Record 43 of Set 12 | anloga
# Processing Record 44 of Set 12 | ballina
# Processing Record 45 of Set 12 | resistencia
# Processing Record 46 of Set 12 | gonen
# Processing Record 47 of Set 12 | sampit
# Processing Record 48 of Set 12 | chernyshevskiy
# Processing Record 49 of Set 12 | mozhaysk
# Processing Record 50 of Set 12 | monrovia
# Processing Record 1 of Set 13 | aguimes
# Processing Record 2 of Set 13 | the valley
# Processing Record 3 of Set 13 | carman
# Processing Record 4 of Set 13 | malanje
# Processing Record 5 of Set 13 | tecoanapa
# Processing Record 6 of Set 13 | oistins
# Processing Record 7 of Set 13 | methoni
# Processing Record 8 of Set 13 | yambio
# Processing Record 9 of Set 13 | qeshm
# Processing Record 10 of Set 13 | roald
# Processing Record 11 of Set 13 | sibolga
# Processing Record 12 of Set 13 | korla
# Processing Record 13 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 14 of Set 13 | kreminna
# Processing Record 15 of Set 13 | umm kaddadah
# Processing Record 16 of Set 13 | micheweni
# Processing Record 17 of Set 13 | pemangkat
# Processing Record 18 of Set 13 | knyaze-volkonskoye
# Processing Record 19 of Set 13 | dalbandin
# Processing Record 20 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 21 of Set 13 | kupang
# Processing Record 22 of Set 13 | worcester
# Processing Record 23 of Set 13 | bilibino
# Processing Record 24 of Set 13 | itacoatiara
# Processing Record 25 of Set 13 | borazjan
# Processing Record 26 of Set 13 | blackwater
# Processing Record 27 of Set 13 | helong
# Processing Record 28 of Set 13 | nabire
# Processing Record 29 of Set 13 | ushtobe
# Processing Record 30 of Set 13 | vanavara
# Processing Record 31 of Set 13 | dwarka
# Processing Record 32 of Set 13 | tipuani
# Processing Record 33 of Set 13 | zhangye
# Processing Record 34 of Set 13 | nybro
# Processing Record 35 of Set 13 | bundaberg
# Processing Record 36 of Set 13 | pristina
# Processing Record 37 of Set 13 | verkhnyaya inta
# Processing Record 38 of Set 13 | san juan de los morros
# Processing Record 39 of Set 13 | skibbereen
# Processing Record 40 of Set 13 | marienburg
# Processing Record 41 of Set 13 | brae
# Processing Record 42 of Set 13 | lobito
# Processing Record 43 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 13 | popondetta
# Processing Record 45 of Set 13 | laguna
# Processing Record 46 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 47 of Set 13 | camana
# Processing Record 48 of Set 13 | the pas
# Processing Record 49 of Set 13 | avera
# Processing Record 50 of Set 13 | carballo
# Processing Record 1 of Set 14 | coquimbo
# Processing Record 2 of Set 14 | laizhou
# Processing Record 3 of Set 14 | yining
# Processing Record 4 of Set 14 | hollister
# Processing Record 5 of Set 14 | riberalta
# Processing Record 6 of Set 14 | nueva germania
# Processing Record 7 of Set 14 | litovko
# Processing Record 8 of Set 14 | ocean city
# Processing Record 9 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 14 | lasa
# Processing Record 11 of Set 14 | touros
# Processing Record 12 of Set 14 | namatanai
# Processing Record 13 of Set 14 | vihari
# Processing Record 14 of Set 14 | ulaangom
# Processing Record 15 of Set 14 | inyonga
# Processing Record 16 of Set 14 | aldama
# Processing Record 17 of Set 14 | iranshahr
# Processing Record 18 of Set 14 | riviere-au-renard
# Processing Record 19 of Set 14 | predivinsk
# Processing Record 20 of Set 14 | inverness
# Processing Record 21 of Set 14 | vilhena
# Processing Record 22 of Set 14 | sembe
# Processing Record 23 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 14 | san vicente
# Processing Record 25 of Set 14 | tamandare
# Processing Record 26 of Set 14 | jos
# Processing Record 27 of Set 14 | taree
# Processing Record 28 of Set 14 | natal
# Processing Record 29 of Set 14 | college
# Processing Record 30 of Set 14 | alamosa
# Processing Record 31 of Set 14 | plastun
# Processing Record 32 of Set 14 | lawar
# City not found. Skipping...
# Processing Record 33 of Set 14 | severobaykalsk
# Processing Record 34 of Set 14 | ambagarh chauki
# Processing Record 35 of Set 14 | maues
# Processing Record 36 of Set 14 | goderich
# Processing Record 37 of Set 14 | pontianak
# Processing Record 38 of Set 14 | bell ville
# Processing Record 39 of Set 14 | rybnaya sloboda
# Processing Record 40 of Set 14 | itaqui
# Processing Record 41 of Set 14 | itarema
# Processing Record 42 of Set 14 | katangli
# Processing Record 43 of Set 14 | buenaventura
# Processing Record 44 of Set 14 | point fortin
# Processing Record 45 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 14 | kiama
# Processing Record 47 of Set 14 | wukari
# Processing Record 48 of Set 14 | jinchang
# Processing Record 49 of Set 14 | tchibanga
# Processing Record 50 of Set 14 | rio gallegos
# Processing Record 1 of Set 15 | bossangoa
# Processing Record 2 of Set 15 | santa cruz de la palma
# Processing Record 3 of Set 15 | luang prabang
# Processing Record 4 of Set 15 | saint-augustin
# Processing Record 5 of Set 15 | sinnamary
# Processing Record 6 of Set 15 | merauke
# Processing Record 7 of Set 15 | stralsund
# Processing Record 8 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 15 | shu
# Processing Record 10 of Set 15 | zlitan
# Processing Record 11 of Set 15 | khorixas
# Processing Record 12 of Set 15 | magadan
# Processing Record 13 of Set 15 | martinsicuro
# Processing Record 14 of Set 15 | sinop
# Processing Record 15 of Set 15 | svay rieng
# Processing Record 16 of Set 15 | yerbogachen
# Processing Record 17 of Set 15 | wanning
# Processing Record 18 of Set 15 | fairbanks
# Processing Record 19 of Set 15 | yeppoon
# Processing Record 20 of Set 15 | jackson
# Processing Record 21 of Set 15 | gornyy
# Processing Record 22 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 15 | prabumulih
# Processing Record 24 of Set 15 | roma
# Processing Record 25 of Set 15 | havre
# Processing Record 26 of Set 15 | asadabad
# Processing Record 27 of Set 15 | karwar
# Processing Record 28 of Set 15 | walvis bay
# Processing Record 29 of Set 15 | marau
# Processing Record 30 of Set 15 | fort nelson
# Processing Record 31 of Set 15 | csaszartoltes
# Processing Record 32 of Set 15 | chicama
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | otjiwarongo
# Processing Record 35 of Set 15 | saint-joseph
# Processing Record 36 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 15 | sawakin
# Processing Record 38 of Set 15 | plouzane
# Processing Record 39 of Set 15 | xuanhua
# Processing Record 40 of Set 15 | saint-paul
# Processing Record 41 of Set 15 | venezuela
# Processing Record 42 of Set 15 | alihe
# Processing Record 43 of Set 15 | arkhara
# Processing Record 44 of Set 15 | bhimunipatnam
# Processing Record 45 of Set 15 | pindushi
# Processing Record 46 of Set 15 | tebingtinggi
# Processing Record 47 of Set 15 | isabela
# Processing Record 48 of Set 15 | sangar
# Processing Record 49 of Set 15 | vernon
# Processing Record 50 of Set 15 | nyimba
# Processing Record 1 of Set 16 | becsehely
# Processing Record 2 of Set 16 | gimli
# Processing Record 3 of Set 16 | ziro
# Processing Record 4 of Set 16 | maniitsoq
# Processing Record 5 of Set 16 | calvinia
# Processing Record 6 of Set 16 | guapore
# Processing Record 7 of Set 16 | te anau
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
city_data_df =pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Marang   5.2056  103.2059     81.10        78          59        1.52
# 1  Yellowknife  62.4560 -114.3525     19.92        49          20        8.05
# 2       Panuco  22.0500  -98.1667     84.29        64          17       16.04
# 3      Ushuaia -54.8000  -68.3000     46.06        93         100       16.11
# 4       Castro -24.7911  -50.0119     52.02        96           8        4.34
#
#   Country                 Date Weather Description
# 0      MY  2022-04-18 00:03:39       broken clouds
# 1      CA  2022-04-17 23:59:02          few clouds
# 2      MX  2022-04-18 00:03:40          few clouds
# 3      AR  2022-04-17 23:59:40       moderate rain
# 4      BR  2022-04-18 00:01:28           clear sky
